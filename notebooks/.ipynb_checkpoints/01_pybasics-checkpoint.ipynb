# %% [markdown]
# # Week 1 — Python Basics
# This notebook covers variables, conditions, loops, lists, and functions.

# %%
print("JupyterLab is working!")
# Out:
# JupyterLab is working!

# %%
name = "Anantha Narayanan"
age = 23
score = 95.5
is_student = True

name, age, score, is_student
# Out:
# ('Anantha Narayanan', 23, 95.5, True)

# %%
if age > 18:
    print("You are an adult.")
else:
    print("You are a minor.")
# Out:
# You are an adult.

# %%
numbers = [10, 20, 30, 40, 50]
print(numbers)
print(numbers[0])
print(numbers[-1])

numbers.append(60)
numbers
# Out:
# [10, 20, 30, 40, 50]
# 10
# 50
# [10, 20, 30, 40, 50, 60]

# %%
for i in range(1, 11):
    print("Value:", i)
# Out:
# Value: 1
# Value: 2
# Value: 3
# Value: 4
# Value: 5
# Value: 6
# Value: 7
# Value: 8
# Value: 9
# Value: 10

# %%
def multiply(a, b):
    return a * b

multiply(6, 7)
# Out:
# 42
